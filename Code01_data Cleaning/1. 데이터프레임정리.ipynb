# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df_agoda=pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/전처리_날짜내림차순/agoda_prepro.csv')
df_airbnb=pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/전처리_날짜내림차순/airbnb_prepro.csv')
df_hotel=pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/전처리_날짜내림차순/hotel_prepro.csv')
df_yanol=pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/전처리_날짜내림차순/yanolja_prepro.csv')
df_yeogi=pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/전처리_날짜내림차순/yeogie_prepro.csv')
df_booking=pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/원데이터/result_booking.csv')
df_dailyhotel=pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/원데이터/result_dailyhotel.csv')
df_expedia=pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/원데이터/result_expedia.csv')
df_hotelscombined=pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/원데이터/result_hotelscombined.csv')
df_interpark=pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/원데이터/result_interpark.csv')
df_myrealtrip=pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/원데이터/result_myrealtrip.csv')
df_skyscanner=pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/원데이터/result_skyscanner.csv')
df_trivago=pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/원데이터/result_trivago.csv')

display(df_agoda.head(2))
display(df_airbnb.head(2))
display(df_hotel.head(2))
display(df_yanol.head(2))
display(df_yeogi.head(2))
# Out:
#    Unnamed: 0 content  score              at
# 0           0    good      5  20230109180233
# 1           1      gg      4  20230109173925
#    Unnamed: 0                               content  score              at
# 0           0                                 편리합니다      5  20230107122726
# 1           1  예약하기도 취소하기도 불편함 해외 원화 결제로 이중 수수료 뭐임?      1  20230107103703
#    Unnamed: 0           content  score              at
# 0           0  비번찾기 불가능. 지우고싶음.      1  20230109113007
# 1           1     리워드 프로그램이 좋아요      5  20230109110342
#    Unnamed: 0   content  score              at
# 0           0     간단해요!      5  20230109175425
# 1           1  한번만들어봤어요      4  20230109173824
#    Unnamed: 0     content  score              at
# 0           0  좋아요~~💯💯💯💯💯      5  20230109153044
# 1           1        유용함ㅣ      5  20230109083628

# %% [markdown]
# ## 전처리 과정

# %%
display(df_agoda.shape)
display(df_airbnb.shape)
display(df_hotel.shape)
display(df_yanol.shape)
display(df_yeogi.shape)
display(df_booking.shape)
display(df_expedia.shape)
display(df_hotelscombined.shape)
display(df_interpark.shape)
display(df_myrealtrip.shape) 
display(df_dailyhotel.shape)
display(df_skyscanner.shape)
display(df_trivago.shape)
# Out:
# (12839, 4)
# (9171, 4)
# (14246, 4)
# (52514, 4)
# (37899, 4)
# (10389, 10)
# (2939, 10)
# (556, 10)
# (1801, 10)
# (4818, 10)
# (45047, 10)
# (11765, 10)
# (719, 10)

# %%
df_booking
# Out:
#                                    reviewId     userName  \
# 0      edbfb5d2-7271-451d-9114-604e483f95fd      kyung B
# 1      241e540d-5779-45ec-aeae-349d7e1d8116       햇빛(햇빛)
# 2      ff65b168-9276-4713-9124-c12804dcaf96     ililiiil
# 3      0317b957-02f3-4b7d-99ec-7b3f86c27967          김기주
# 4      db60c08d-fc4d-4fe2-a731-0e462a3a86d0          박승호
# ...                                     ...          ...
# 10384  e5c4b028-ee4f-4656-b520-b6b9542b1388   Google 사용자
# 10385  72415e8d-b9ab-472c-b59b-75a104274575   Google 사용자
# 10386  a567c29b-b2aa-4d9d-91d5-30263c4713d0   Google 사용자
# 10387  1ea4e71e-4528-4aac-9a82-0b06dc2d9db2  kykyung lee
# 10388  7db74824-7e70-4f8c-a270-341b37df3a9d       Leo Yu
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a/AEdFTp...
# 1      https://play-lh.googleusercontent.com/a-/AD5-W...
# 2      https://play-lh.googleusercontent.com/a/AEdFTp...
# ...

# %% [markdown]
# ### 필요없는 칼럼 제거

# %%
df_booking = df_booking.drop(columns = ['reviewId','userName','userImage','thumbsUpCount','reviewCreatedVersion','replyContent','repliedAt'])
df_expedia = df_expedia.drop(columns = ['reviewId','userName','userImage','thumbsUpCount','reviewCreatedVersion','replyContent','repliedAt'])
df_hotelscombined = df_hotelscombined.drop(columns = ['reviewId','userName','userImage','thumbsUpCount','reviewCreatedVersion','replyContent','repliedAt'])
df_interpark = df_interpark.drop(columns = ['reviewId','userName','userImage','thumbsUpCount','reviewCreatedVersion','replyContent','repliedAt'])
df_myrealtrip = df_myrealtrip.drop(columns = ['reviewId','userName','userImage','thumbsUpCount','reviewCreatedVersion','replyContent','repliedAt'])
df_dailyhotel = df_dailyhotel.drop(columns = ['reviewId','userName','userImage','thumbsUpCount','reviewCreatedVersion','replyContent','repliedAt'])
df_skyscanner = df_skyscanner.drop(columns = ['reviewId','userName','userImage','thumbsUpCount','reviewCreatedVersion','replyContent','repliedAt'])
df_trivago = df_trivago.drop(columns = ['reviewId','userName','userImage','thumbsUpCount','reviewCreatedVersion','replyContent','repliedAt'])

# %%
df_booking
# Out:
#                                                  content  score  \
# 0      예약전에 궁금한 점이 있을 경우 앱을 통해 호스트와 메시지로 소통하는 것이 아주 효...      5
# 1      원하는 숙소를 28만원대라길래 들어갔다가 33만원대에 예약해두고 결제일을 기다리는 ...      1
# 2      네이버로 가입했으면 어플에서 로그인 자체가 안됩니다. 로그인 버튼이없습니다. 네이버...      1
# 3      숙소 예약에는 몇번 잘 사용했던터라 렌트카 예약도 했었는데 공항 도착해서보니 렌트카...      1
# 4      이 회사 쓰지마세요. 거의 여행다니면서 10번 20번 가량에 예약을 하며 잘 이용했...      1
# ...                                                  ...    ...
# 10384                                               Good      4
# 10385                                               Good      5
# 10386                                                별로다      1
# 10387                                                편해요      5
# 10388  This app is a trash. Horrible Customer Service...      1
#
#                         at
# 0      2023-02-05 19:16:29
# 1      2022-12-30 11:36:11
# 2      2022-12-21 14:47:02
# 3      2022-12-14 12:23:00
# 4      2022-12-12 16:45:41
# ...                    ...
# ...

# %% [markdown]
# ### 날짜 숫자만 남기기

# %%
import re

df_booking["at"] = df_booking["at"].str.replace(r'[^0-9]','')
df_expedia["at"] = df_expedia["at"].str.replace(r'[^0-9]','')
df_hotelscombined["at"] = df_hotelscombined["at"].str.replace(r'[^0-9]','')
df_interpark["at"] = df_interpark["at"].str.replace(r'[^0-9]','')
df_myrealtrip["at"] = df_myrealtrip["at"].str.replace(r'[^0-9]','')
df_dailyhotel["at"] = df_dailyhotel["at"].str.replace(r'[^0-9]','')
df_skyscanner["at"] = df_skyscanner["at"].str.replace(r'[^0-9]','')
df_trivago["at"] = df_trivago["at"].str.replace(r'[^0-9]','')

df_booking
# Out:
# <ipython-input-25-10603fbc7137>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_booking["at"] = df_booking["at"].str.replace(r'[^0-9]','')
# <ipython-input-25-10603fbc7137>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_expedia["at"] = df_expedia["at"].str.replace(r'[^0-9]','')
# <ipython-input-25-10603fbc7137>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_hotelscombined["at"] = df_hotelscombined["at"].str.replace(r'[^0-9]','')
# <ipython-input-25-10603fbc7137>:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_interpark["at"] = df_interpark["at"].str.replace(r'[^0-9]','')
# <ipython-input-25-10603fbc7137>:7: FutureWarning: The default value of regex will change from True to False in a future version.
# ...

# %%
display(df_agoda.shape)
display(df_airbnb.shape)
display(df_hotel.shape)
display(df_yanol.shape)
display(df_yeogi.shape)
display(df_booking.shape)
display(df_expedia.shape)
display(df_hotelscombined.shape)
display(df_interpark.shape)
display(df_myrealtrip.shape) 
display(df_dailyhotel.shape)
display(df_skyscanner.shape)
display(df_trivago.shape)
# Out:
# (12839, 4)
# (9171, 4)
# (14246, 4)
# (52514, 4)
# (37899, 4)
# (10389, 3)
# (2939, 3)
# (556, 3)
# (1801, 3)
# (4818, 3)
# (45047, 3)
# (11765, 3)
# (719, 3)

# %%
df_agoda
# Out:
#        Unnamed: 0                                            content  score  \
# 0               0                                               good      5
# 1               1                                                 gg      4
# 2               2                                      너무 저렴하니 좋습니다.      5
# 3               3                         캐시백 미적용가격으로 볼수있게 하는기능 필요할듯      4
# 4               4  결제 가 이상하게 됨 분명 40만원이 1시간 간격으로 2번 결제 됐는데 환불 했더니...      1
# ...           ...                                                ...    ...
# 12834       12834  중심에 위치해 있고 리노베이션 되어서 깔끔하고....단 전기포트에 물을 끓일려고 했...      4
# 12835       12835                     원래 아고다싸이트로 해외호텔예약해왔는데 어플도되니 쵝오      4
# 12836       12836                             포인트 ㅅ사아다 사용하는 맛이 솔솔합디다      5
# 12837       12837              내 주변 호텔찾기는 편한데.. 호텔 이름으로 찾기 기능이 없다...      4
# 12838       12838                                            실행오류 잘남      1
#
#                    at
# 0      20230109180233
# ...

# %%
#df_booking = df_booking.drop(columns = ['reviewId','userName','userImage','thumbsUpCount','reviewCreatedVersion','replyContent','repliedAt'])
df_agoda.columns
# Out:
# Index(['Unnamed: 0', 'content', 'score', 'at'], dtype='object')

# %%
df_agoda = df_agoda.drop(columns = 'Unnamed: 0')
df_airbnb = df_airbnb.drop(columns = 'Unnamed: 0')
df_hotelsdotcom = df_hotel.drop(columns = 'Unnamed: 0')
df_yanol = df_yanol.drop(columns = 'Unnamed: 0')
df_yeogi = df_yeogi.drop(columns = 'Unnamed: 0')

# %%
display(df_agoda.shape)
display(df_airbnb.shape)
display(df_hotelsdotcom.shape)
display(df_yanol.shape)
display(df_yeogi.shape)
# Out:
# (12839, 3)
# (9171, 3)
# (14246, 3)
# (52514, 3)
# (37899, 3)

# %%
# df = df.sort_values(by=['칼럼1'], axis=0, ascending = False)
df_agoda = df_agoda.sort_values(by=['at'], axis=0, ascending = False)
df_airbnb = df_airbnb.sort_values(by=['at'], axis=0, ascending = False)
df_hotelsdotcom = df_hotelsdotcom.sort_values(by=['at'], axis=0, ascending = False)
df_yanol = df_yanol.sort_values(by=['at'], axis=0, ascending = False)
df_yeogi = df_yeogi.sort_values(by=['at'], axis=0, ascending = False)
df_booking = df_booking.sort_values(by=['at'], axis=0, ascending = False)
df_expedia = df_expedia.sort_values(by=['at'], axis=0, ascending = False)
df_hotelscombined = df_hotelscombined.sort_values(by=['at'], axis=0, ascending = False)
df_interpark = df_interpark.sort_values(by=['at'], axis=0, ascending = False)
df_myrealtrip = df_myrealtrip.sort_values(by=['at'], axis=0, ascending = False)
df_dailyhotel = df_dailyhotel.sort_values(by=['at'], axis=0, ascending = False)
df_skyscanner = df_skyscanner.sort_values(by=['at'], axis=0, ascending = False)
df_trivago = df_trivago.sort_values(by=['at'], axis=0, ascending = False)

display(df_agoda.head())
display(df_airbnb.head())
display(df_hotel.head())
display(df_yanol.head())
display(df_yeogi.head())
display(df_booking.head())
display(df_expedia.head())
display(df_hotelscombined.head())
display(df_interpark.head())
display(df_myrealtrip.head()) 
display(df_dailyhotel.head())
display(df_skyscanner.head())
display(df_trivago.head())
# Out:
#                                              content  score              at
# 0                                               good      5  20230109180233
# 1                                                 gg      4  20230109173925
# 2                                      너무 저렴하니 좋습니다.      5  20230109164020
# 3                         캐시백 미적용가격으로 볼수있게 하는기능 필요할듯      4  20230109143521
# 4  결제 가 이상하게 됨 분명 40만원이 1시간 간격으로 2번 결제 됐는데 환불 했더니...      1  20230109095449
#                                              content  score              at
# 0                                              편리합니다      5  20230107122726
# 1               예약하기도 취소하기도 불편함 해외 원화 결제로 이중 수수료 뭐임?      1  20230107103703
# 2  Airbnb support team was so helpful when I had ...      5  20230107021510
# 3                                    숙소찾기가 편리하고 좋습니다      5  20230107020055
# 4  아니 이거 예약하려는데 핸드폰등록한적이 없는데 등록이 되어있다고 하는데 인증횟수도 ...      1  20230106210609
# ...

# %%
df_agoda = df_agoda.reset_index(drop=True)
df_airbnb = df_airbnb.reset_index(drop=True)
df_hotelsdotcom = df_hotelsdotcom.reset_index(drop=True)
df_yanol = df_yanol.reset_index(drop=True)
df_yeogi = df_yeogi.reset_index(drop=True)
df_booking = df_booking.reset_index(drop=True)
df_expedia = df_expedia.reset_index(drop=True)
df_hotelscombined = df_hotelscombined.reset_index(drop=True)
df_interpark = df_interpark.reset_index(drop=True)
df_myrealtrip = df_myrealtrip.reset_index(drop=True)
df_dailyhotel = df_dailyhotel.reset_index(drop=True)
df_skyscanner = df_skyscanner.reset_index(drop=True)
df_trivago = df_trivago.reset_index(drop=True)

display(df_myrealtrip)
# Out:
#                                                 content  score              at
# 0                       항공,렌트를 저렴하게 한번에 예약해서 잘 놀다 왔습니다~      4  20230206185732
# 1     낮에는 두 아이들과 다녔던 코스를 밤에 가이드님과 함께 상세한 설명을 들으면서 투어...      5  20230206165709
# 2         제주여행시 자주 사용하는데 편리하고 좋습니다. 렌트카 쪽이 잘되어 있는거 같아요~      4  20230204154641
# 3                                                정보가많아요      5  20230202123333
# 4        대체로 합리적인 가격에 처음 이용해도 불편함없이 투어가 순조롭게 진행되어 좋았습니다      5  20230201171258
# ...                                                 ...    ...             ...
# 4813         패키지와 다른 매력이 있는 여행이군요 현지인과 함께 의미있는 여행이었습니다.      5  20141223232526
# 4814            패키지 여행은 항상 아쉬웠는데 마이리얼트립에는 특별한 상품들이 많네요!      5  20141223220845
# 4815                  구글검색에서 가장 위에 뜨지 않아서 아직 안나온줄 알았어요.      5  20141223215057
# 4816  마이리얼트립과 함께라면 어느 곳을 가더라도 즐겁게 여행할 수 있을거 같아요. 앱도 ...      5  20141223214813
# 4817                                         여행가고 싶어지네여      5  20141223205914
#
# [4818 rows x 3 columns]

# %% [markdown]
# ### 날짜별 내림차순
#
# - 이 단계까지 저장

# %%
display(df_myrealtrip.shape)
# Out:
# (4818, 3)

# %%
df_trivago.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_trivago.csv',index_label='date')
df_airbnb.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_airbnb.csv',index_label='date')
df_hotelsdotcom.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_hotelsdotcom.csv',index_label='date')
df_yanol.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_yanol.csv',index_label='date')
df_yeogi.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_yeogi.csv',index_label='date')
df_booking.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_booking.csv',index_label='date')
df_expedia.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_expedia.csv',index_label='date')
df_hotelscombined.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_hotelscombined.csv',index_label='date')
df_interpark.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_interpark.csv',index_label='date')
df_myrealtrip.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_myrealtrip.csv',index_label='date')
df_dailyhotel.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_dailyhotel.csv',index_label='date')
df_skyscanner.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_skyscanner.csv',index_label='date')
