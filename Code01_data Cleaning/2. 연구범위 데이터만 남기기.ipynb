# %% [markdown]
# ## 연구범위
#
# - 2020~2022을 제외한 데이터 제거

# %% [markdown]
# ### agoda 데이터

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df_agoda = pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_agoda.csv')

df_agoda
# Out:
#         date                                            content  score  \
# 0          0                                               good      5
# 1          1                                                 gg      4
# 2          2                                      너무 저렴하니 좋습니다.      5
# 3          3                         캐시백 미적용가격으로 볼수있게 하는기능 필요할듯      4
# 4          4  결제 가 이상하게 됨 분명 40만원이 1시간 간격으로 2번 결제 됐는데 환불 했더니...      1
# ...      ...                                                ...    ...
# 12834  12834  중심에 위치해 있고 리노베이션 되어서 깔끔하고....단 전기포트에 물을 끓일려고 했...      4
# 12835  12835                     원래 아고다싸이트로 해외호텔예약해왔는데 어플도되니 쵝오      4
# 12836  12836                             포인트 ㅅ사아다 사용하는 맛이 솔솔합디다      5
# 12837  12837              내 주변 호텔찾기는 편한데.. 호텔 이름으로 찾기 기능이 없다...      4
# 12838  12838                                            실행오류 잘남      1
#
#                    at
# 0      20230109180233
# 1      20230109173925
# 2      20230109164020
# ...

# %% [markdown]
# #### 2020년 이후 데이터셋

# %%
df_agoda = df_agoda[(df_agoda['at']>=20190000000000) & (df_agoda['at']<20230000000000)]

df_agoda.shape
# Out:
# (6098, 4)

# %%
df_agoda
# Out:
#       date                                            content  score  \
# 73      73                                               good      5
# 74      74                         사용 후기를 통해 쉽게 예매 할 수 있어 좋아요      5
# 75      75                                               good      3
# 76      76                                                좋아요      5
# 77      77                    세금포함 최종가격 올려 주는 기능은 없나요? 혼동 되네요      4
# ...    ...                                                ...    ...
# 3999  3999                                               좋습니다      5
# 4000  4000  진짜 개똥같은 기업이네요 자기네가 돈 빼가놓고는 호탤측은 못받았다고 하고 아고다 다...      1
# 4001  4001                             여행갈때는 항상 아고다에서 호텔잡고 가요      5
# 4002  4002  일단 확실히 편하게 호텔에대해 알게되었습니다 사진정보 위치 다좋았고요 예약이 잘못되...      5
# 4003  4003                                문제가있었는데 잘 처리해주시네요^^      5
#
#                   at
# 73    20221231232711
# 74    20221231223041
# 75    20221231215947
# 76    20221231162546
# 77    20221231142125
# ...

# %% [markdown]
# #### 각 연도 별 데이터 개수

# %%
df_agoda_2020 = df_agoda[(df_agoda['at']>=20200000000000) & (df_agoda['at']<20210000000000)]
df_agoda_2021 = df_agoda[(df_agoda['at']>=20210000000000) & (df_agoda['at']<20220000000000)]
df_agoda_2022 = df_agoda[(df_agoda['at']>=20220000000000) & (df_agoda['at']<20230000000000)]

display(df_agoda_2020.shape)
display(df_agoda_2021.shape)
display(df_agoda_2022.shape)
# Out:
# (972, 4)
# (1328, 4)
# (1631, 4)

# %% [markdown]
# #### 2020~2022 데이터 저장

# %%
df_agoda.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/연구범위데이터(2020~2022)/df_agoda.csv',index_label='date')

# %% [markdown]
# ### airbnb 데이터

# %%
df_airbnb = pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_airbnb.csv')

df_airbnb
# Out:
#       date                                            content  score  \
# 0        0                                              편리합니다      5
# 1        1               예약하기도 취소하기도 불편함 해외 원화 결제로 이중 수수료 뭐임?      1
# 2        2  Airbnb support team was so helpful when I had ...      5
# 3        3                                    숙소찾기가 편리하고 좋습니다      5
# 4        4  아니 이거 예약하려는데 핸드폰등록한적이 없는데 등록이 되어있다고 하는데 인증횟수도 ...      1
# ...    ...                                                ...    ...
# 9166  9166  This Application is the best that I ever seen ...      5
# 9167  9167                                               good      5
# 9168  9168                 옵g프로에서 메세지 보내면 한글이 전부 깨지네요 개선 바랍니다      2
# 9169  9169                                                 대박      5
# 9170  9170  Everytime I tried with airbnb the result was t...      5
#
#                   at
# 0     20230107122726
# 1     20230107103703
# 2     20230107021510
# 3     20230107020055
# 4     20230106210609
# ...

# %%
df_airbnb = df_airbnb[(df_airbnb['at']>=20200000000000) & (df_airbnb['at']<20230000000000)]

df_airbnb.shape
# Out:
# (2904, 4)

# %%
df_airbnb
# Out:
#       date                                            content  score  \
# 22      22  신분증 인증 사진을 도대체 얼마나 선명하게 찍어 올리라는 겁니까??? 다섯 번째 다...      1
# 23      23           thet are getting too much info by mobile      2
# 24      24                                           그냥 맘에 안듬      1
# 25      25                            편리하나 강비절차가 복잡하고 시간이 소요됨      4
# 26      26  저 같은 피해자가 생기지 않길 간절히 바라는 마음으로 리뷰를 씁니다. 환불정책을 꼭...      1
# ...    ...                                                ...    ...
# 2921  2921                                               좋아요~      5
# 2922  2922       좋은 앱입니다. 하지만 걔중에 나쁜 호스트도 있겠지요. 나쁜 게스트도 있겠구요.      5
# 2923  2923                                               good      5
# 2924  2924                          여행비용을 아끼고 만족스러운 여행을 했습니다!      5
# 2925  2925                                        세상완벽한어플리케이션      5
#
#                   at
# 22    20221231184330
# 23    20221230162613
# 24    20221230161934
# 25    20221229171706
# 26    20221229104106
# ...

# %%
df_airbnb_2020 = df_airbnb[(df_airbnb['at']>=20200000000000) & (df_airbnb['at']<20210000000000)]
df_airbnb_2021 = df_airbnb[(df_airbnb['at']>=20210000000000) & (df_airbnb['at']<20220000000000)]
df_airbnb_2022 = df_airbnb[(df_airbnb['at']>=20220000000000) & (df_airbnb['at']<20230000000000)]

display(df_airbnb_2020.shape)
display(df_airbnb_2021.shape)
display(df_airbnb_2022.shape)
# Out:
# (1186, 4)
# (893, 4)
# (825, 4)

# %%
df_airbnb.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/연구범위데이터(2020~2022)/df_airbnb.csv',index_label='date')

# %% [markdown]
# ### 그 밖의 데이터

# %%
df_booking = pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_booking.csv')
df_dailyhotel = pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_dailyhotel.csv')
df_expedia = pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_expedia.csv')
df_hotelscombined = pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_hotelscombined.csv')
df_hotelsdotcom = pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_hotelsdotcom.csv')
df_interpark = pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_interpark.csv')
df_myrealtrip = pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_myrealtrip.csv')
df_skyscanner = pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_skyscanner.csv')
df_trivago = pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_trivago.csv')
df_yanol = pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_yanol.csv')
df_yeogi = pd.read_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/날짜내림차순/df_yeogi.csv')

# %%
df_booking = df_booking[(df_booking['at']>=20200000000000) & (df_booking['at']<20230000000000)]
df_dailyhotel = df_dailyhotel[(df_dailyhotel['at']>=20200000000000) & (df_dailyhotel['at']<20230000000000)]
df_expedia = df_expedia[(df_expedia['at']>=20200000000000) & (df_expedia['at']<20230000000000)]
df_hotelscombined = df_hotelscombined[(df_hotelscombined['at']>=20200000000000) & (df_hotelscombined['at']<20230000000000)]
df_hotelsdotcom = df_hotelsdotcom[(df_hotelsdotcom['at']>=20200000000000) & (df_hotelsdotcom['at']<20230000000000)]
df_interpark = df_interpark[(df_interpark['at']>=20200000000000) & (df_interpark['at']<20230000000000)]
df_myrealtrip = df_myrealtrip[(df_myrealtrip['at']>=20200000000000) & (df_myrealtrip['at']<20230000000000)]
df_skyscanner = df_skyscanner[(df_skyscanner['at']>=20200000000000) & (df_skyscanner['at']<20230000000000)]
df_trivago = df_trivago[(df_trivago['at']>=20200000000000) & (df_trivago['at']<20230000000000)]
df_yanol = df_yanol[(df_yanol['at']>=20200000000000) & (df_yanol['at']<20230000000000)]
df_yeogi = df_yeogi[(df_yeogi['at']>=20200000000000) & (df_yeogi['at']<20230000000000)]

# %%
display(df_booking.shape)
display(df_dailyhotel.shape)
display(df_expedia.shape)
display(df_hotelscombined.shape)
display(df_hotelsdotcom.shape)
display(df_interpark.shape)
display(df_myrealtrip.shape)
display(df_skyscanner.shape)
display(df_trivago.shape)
display(df_yanol.shape)
display(df_yeogi.shape)
# Out:
# (1694, 4)
# (6761, 4)
# (371, 4)
# (170, 4)
# (2125, 4)
# (236, 4)
# (886, 4)
# (483, 4)
# (74, 4)
# (13769, 4)
# (4952, 4)

# %%
df_2020 = df_booking[(df_booking['at']>=20200000000000) & (df_booking['at']<20210000000000)]
df_2021 = df_booking[(df_booking['at']>=20210000000000) & (df_booking['at']<20220000000000)]
df_2022 = df_booking[(df_booking['at']>=20220000000000) & (df_booking['at']<20230000000000)]

display(df_2020.shape)
display(df_2021.shape)
display(df_2022.shape)
# Out:
# (827, 4)
# (362, 4)
# (505, 4)

# %%
df_2020 = df_dailyhotel[(df_dailyhotel['at']>=20200000000000) & (df_dailyhotel['at']<20210000000000)]
df_2021 = df_dailyhotel[(df_dailyhotel['at']>=20210000000000) & (df_dailyhotel['at']<20220000000000)]
df_2022 = df_dailyhotel[(df_dailyhotel['at']>=20220000000000) & (df_dailyhotel['at']<20230000000000)]

display(df_2020.shape)
display(df_2021.shape)
display(df_2022.shape)
# Out:
# (4732, 4)
# (1906, 4)
# (123, 4)

# %%
df_2020 = df_expedia[(df_expedia['at']>=20200000000000) & (df_expedia['at']<20210000000000)]
df_2021 = df_expedia[(df_expedia['at']>=20210000000000) & (df_expedia['at']<20220000000000)]
df_2022 = df_expedia[(df_expedia['at']>=20220000000000) & (df_expedia['at']<20230000000000)]

display(df_2020.shape)
display(df_2021.shape)
display(df_2022.shape)
# Out:
# (207, 4)
# (27, 4)
# (137, 4)

# %%
df_2020 = df_hotelscombined[(df_hotelscombined['at']>=20200000000000) & (df_hotelscombined['at']<20210000000000)]
df_2021 = df_hotelscombined[(df_hotelscombined['at']>=20210000000000) & (df_hotelscombined['at']<20220000000000)]
df_2022 = df_hotelscombined[(df_hotelscombined['at']>=20220000000000) & (df_hotelscombined['at']<20230000000000)]

display(df_2020.shape)
display(df_2021.shape)
display(df_2022.shape)
# Out:
# (53, 4)
# (59, 4)
# (58, 4)

# %%
df_2020 = df_hotelsdotcom[(df_hotelsdotcom['at']>=20200000000000) & (df_hotelsdotcom['at']<20210000000000)]
df_2021 = df_hotelsdotcom[(df_hotelsdotcom['at']>=20210000000000) & (df_hotelsdotcom['at']<20220000000000)]
df_2022 = df_hotelsdotcom[(df_hotelsdotcom['at']>=20220000000000) & (df_hotelsdotcom['at']<20230000000000)]

display(df_2020.shape)
display(df_2021.shape)
display(df_2022.shape)
# Out:
# (765, 4)
# (482, 4)
# (878, 4)

# %%
df_2020 = df_interpark[(df_interpark['at']>=20200000000000) & (df_interpark['at']<20210000000000)]
df_2021 = df_interpark[(df_interpark['at']>=20210000000000) & (df_interpark['at']<20220000000000)]
df_2022 = df_interpark[(df_interpark['at']>=20220000000000) & (df_interpark['at']<20230000000000)]

display(df_2020.shape)
display(df_2021.shape)
display(df_2022.shape)
# Out:
# (71, 4)
# (69, 4)
# (96, 4)

# %%
df_2020 = df_myrealtrip[(df_myrealtrip['at']>=20200000000000) & (df_myrealtrip['at']<20210000000000)]
df_2021 = df_myrealtrip[(df_myrealtrip['at']>=20210000000000) & (df_myrealtrip['at']<20220000000000)]
df_2022 = df_myrealtrip[(df_myrealtrip['at']>=20220000000000) & (df_myrealtrip['at']<20230000000000)]

display(df_2020.shape)
display(df_2021.shape)
display(df_2022.shape)
# Out:
# (537, 4)
# (193, 4)
# (156, 4)

# %%
df_2020 = df_skyscanner[(df_skyscanner['at']>=20200000000000) & (df_skyscanner['at']<20210000000000)]
df_2021 = df_skyscanner[(df_skyscanner['at']>=20210000000000) & (df_skyscanner['at']<20220000000000)]
df_2022 = df_skyscanner[(df_skyscanner['at']>=20220000000000) & (df_skyscanner['at']<20230000000000)]

display(df_2020.shape)
display(df_2021.shape)
display(df_2022.shape)
# Out:
# (113, 4)
# (164, 4)
# (206, 4)

# %%
df_2020 = df_trivago[(df_trivago['at']>=20200000000000) & (df_trivago['at']<20210000000000)]
df_2021 = df_trivago[(df_trivago['at']>=20210000000000) & (df_trivago['at']<20220000000000)]
df_2022 = df_trivago[(df_trivago['at']>=20220000000000) & (df_trivago['at']<20230000000000)]

display(df_2020.shape)
display(df_2021.shape)
display(df_2022.shape)
# Out:
# (47, 4)
# (17, 4)
# (10, 4)

# %%
df_2020 = df_yanol[(df_yanol['at']>=20200000000000) & (df_yanol['at']<20210000000000)]
df_2021 = df_yanol[(df_yanol['at']>=20210000000000) & (df_yanol['at']<20220000000000)]
df_2022 = df_yanol[(df_yanol['at']>=20220000000000) & (df_yanol['at']<20230000000000)]

display(df_2020.shape)
display(df_2021.shape)
display(df_2022.shape)
# Out:
# (5367, 4)
# (3622, 4)
# (4780, 4)

# %%
df_2020 = df_yeogi[(df_yeogi['at']>=20200000000000) & (df_yeogi['at']<20210000000000)]
df_2021 = df_yeogi[(df_yeogi['at']>=20210000000000) & (df_yeogi['at']<20220000000000)]
df_2022 = df_yeogi[(df_yeogi['at']>=20220000000000) & (df_yeogi['at']<20230000000000)]

display(df_2020.shape)
display(df_2021.shape)
display(df_2022.shape)
# Out:
# (1392, 4)
# (1249, 4)
# (2311, 4)

# %%
df_booking.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/연구범위데이터(2020~2022)/df_booking.csv',index_label='date')
df_dailyhotel.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/연구범위데이터(2020~2022)/df_dailyhotel.csv',index_label='date')
df_expedia.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/연구범위데이터(2020~2022)/df_expedia.csv',index_label='date')
df_hotelscombined.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/연구범위데이터(2020~2022)/df_hotelscombined.csv',index_label='date')
df_hotelsdotcom.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/연구범위데이터(2020~2022)/df_hotelsdotcom.csv',index_label='date')
df_interpark.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/연구범위데이터(2020~2022)/df_interpark.csv',index_label='date')
df_myrealtrip.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/연구범위데이터(2020~2022)/df_myrealtrip.csv',index_label='date')
df_skyscanner.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/연구범위데이터(2020~2022)/df_skyscanner.csv',index_label='date')
df_trivago.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/연구범위데이터(2020~2022)/df_trivago.csv',index_label='date')
df_yanol.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/연구범위데이터(2020~2022)/df_yanol.csv',index_label='date')
df_yeogi.to_csv('/content/drive/MyDrive/리뷰데이터 분석/데이터셋/데이터함/연구범위데이터(2020~2022)/df_yeogi.csv',index_label='date')
